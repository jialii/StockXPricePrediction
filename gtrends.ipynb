# %% [markdown]
# Older code containing unused Google Trends scrape

# %%
import requests
import pandas as pd
import json

# %%
def getToken(searchQuery):
    
    url = f"https://trends.google.com/trends/api/explore?hl=en-GB&tz=300&req=%7B%22comparisonItem%22:%5B%7B%22keyword%22:%22{searchQuery}%22,%22geo%22:%22US%22,%22time%22:%22today+1-m%22%7D%5D,%22category%22:0,%22property%22:%22%22%7D&tz=300"

    payload={}
    headers = {
    'authority': 'trends.google.com',
    'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="96", "Google Chrome";v="96"',
    'accept': 'application/json, text/plain, */*',
    'sec-ch-ua-mobile': '?0',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36',
    'sec-ch-ua-platform': '"Windows"',
    'x-client-data': 'CKK1yQEIjLbJAQimtskBCMG2yQEIqZ3KAQjW0coBCLWKywEI6vLLAQie+csBCOaEzAEI+YTMAQi1hcwBCMuJzAEIoIvMAQisjswBGIOFzAE=',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://trends.google.com/trends/explore?date=today%201-m&geo=US&q=nike%20dunk',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': '__utmz=10102256.1632351086.1.1.utmcsr=google|utmccn=(organic)|utmcmd=organic|utmctr=(not%20provided); __utmc=10102256; __utma=10102256.1770031370.1632351086.1637368835.1637463786.6; __utmt=1; __utmb=10102256.9.9.1637463905732; ANID=AHWqTUlXGzfwZQPJd10fU6nmrM609at8wy5FYUAG40U6blctU4l05gtkwk_-O4o5; OGPC=19026101-2:; SID=DgjpyxtQF0NdSe33bTAf-CT6qunorIZvzUo5HuE0GYxlxnRuYyR4Ko1MMMj-4G97B_fVIg.; __Secure-1PSID=DgjpyxtQF0NdSe33bTAf-CT6qunorIZvzUo5HuE0GYxlxnRurr3IaqexEZt5bkleCr89Zg.; __Secure-3PSID=DgjpyxtQF0NdSe33bTAf-CT6qunorIZvzUo5HuE0GYxlxnRux76od47JwWmUwivK5yEN_w.; HSID=A746yAtNPSdZ1UXol; SSID=ANGNQ6_0pc1uimsU1; APISID=x9DJ6l6fLYu-lqYd/AC5Jx-8fYKTcUsfnE; SAPISID=_xNZuLfrPAdBCto7/ApDHAZJDoN-aKtrNA; __Secure-1PAPISID=_xNZuLfrPAdBCto7/ApDHAZJDoN-aKtrNA; __Secure-3PAPISID=_xNZuLfrPAdBCto7/ApDHAZJDoN-aKtrNA; SEARCH_SAMESITE=CgQIhZQB; 1P_JAR=2021-11-21-00; NID=511=mucyzoy5BnkGFZUqraA3L3uuDYhhg-4eay_eHePrpEFRc6selkfYOcnmsdIKeHEKQ1thhkI9fM3s6ogJzBF3Zy9Xf1E_EeEb7zbRemF2aC3Hp7daIKpnSpdbAzoB-Zusq6ARtd1WmEiacGdEw_2c8uU4-FTl04wezIgWVUuoRp3cyJpA4kdOPdSwYJF3DuJSg4pH-jwNlrvVSdmKen8TzztBRI_U8awJpYpcGQr2yerc6vVg8PMfydaGjvSyBGpUBmSPQeyy0x2bjI-SBJ6w2W8NXXZ2xmktpZmDaTWQSlEirxUqlHJj4jzp7PnIABui5Rx4STMsKJNLLeArkUE1zrz9Yl21Cg0fn4QP73ASyYxOitwrvzaSYsU; SIDCC=AJi4QfFqZq1R0XksSjdipKZKJZOAdlPUnnOJ_3alZGS_CsVKoBrpJdQhgJzhDlToxI0BLy8rarY; __Secure-3PSIDCC=AJi4QfFvRA674TDmh80aI7jaWc833rxQih3rYUBEuYPCTBHO-Pc5a0lB3FTFXZ90mmeJfD0gyL8; SIDCC=AJi4QfF7tAfK3aecn6fHqSMGcWAdb28bH336PaC0wDKDXh2OYel6tENht42BGR1iY9A3KMSC4Kg; __Secure-3PSIDCC=AJi4QfET7Oz2zGboFWqUDxaV5qTojWRSm2xPase1rhqjs5SvhOoMy_5F61s8Xhq3EzLF9Zly0lE'
    }

    response = requests.request("GET", url, headers=headers, data=payload)
    return json.loads(response.text.split('\n')[1])["widgets"][0]["token"]

# %%
getToken("Nike Dunk Low")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-5d5036ec8854> in <module>
# ----> 1 getToken("Nike Dunk Low")
#
# <ipython-input-17-586c8ba8750f> in getToken(searchQuery)
#      21
#      22     response = requests.request("GET", url, headers=headers, data=payload)
# ---> 23     return json.loads(response.text.split('\n')[1])["widgets"][0]["token"]
#      24
#
# IndexError: list index out of range

# %%
def getSearchData(query):
    token = getToken(query)

    url = f"https://trends.google.com/trends/api/widgetdata/multiline?hl=en-US&tz=300&req=%7B%22time%22:%222021-10-20+2021-11-20%22,%22resolution%22:%22DAY%22,%22locale%22:%22en-US%22,%22comparisonItem%22:%5B%7B%22geo%22:%7B%22country%22:%22US%22%7D,%22complexKeywordsRestriction%22:%7B%22keyword%22:%5B%7B%22type%22:%22BROAD%22,%22value%22:%22{query}%22%7D%5D%7D%7D%5D,%22requestOptions%22:%7B%22property%22:%22%22,%22backend%22:%22IZG%22,%22category%22:0%7D%7D&token={token}&tz=300"

    payload={}
    headers = {
    'authority': 'trends.google.com',
    'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="96", "Google Chrome";v="96"',
    'accept': 'application/json, text/plain, */*',
    'sec-ch-ua-mobile': '?0',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://trends.google.com/trends/explore?date=today%201-m&geo=US&q=Nike%20Dunk%20Low%20Georgetown',
    'accept-language': 'en-US,en;q=0.9',
    # 'cookie': '__utma=10102256.33302800.1637368928.1637368928.1637368928.1; __utmc=10102256; __utmz=10102256.1637368928.1.1.utmcsr=(direct)|utmccn=(direct)|utmcmd=(none); __utmt=1; __utmb=10102256.12.9.1637368953817; NID=511=aEVB7sxUL_JWWIKHQfJ0md1w8ftNiE3Cfgd0zPUU76qrKRqHHbuXCcXHpxKg_mW0dDdR1jb9zuQMDY0oiAdKF22sjVAwKOB_EUa-npqgMW7aqiMI865y6LqHSYzim67whzcH-BwXdG6GQk_eP7JW5iI0_7dyIoXKH-rWQK3qShY; SIDCC=AJi4QfF7tAfK3aecn6fHqSMGcWAdb28bH336PaC0wDKDXh2OYel6tENht42BGR1iY9A3KMSC4Kg; __Secure-3PSIDCC=AJi4QfET7Oz2zGboFWqUDxaV5qTojWRSm2xPase1rhqjs5SvhOoMy_5F61s8Xhq3EzLF9Zly0lE'
    }

    response = requests.request("GET", url, headers=headers, data=payload)

    print(response.text)

# %%
getSearchData("Nike Dunk Low")
# Out:
# <html lang=en><meta charset=utf-8><meta name=viewport content="initial-scale=1, minimum-scale=1, width=device-width"><title>Error 401 (Bad Request)!!1</title><style nonce="pQV6dxLb1jMP5tXMShG6yg">*{margin:0;padding:0}html,code{font:15px/22px arial,sans-serif}html{background:#fff;color:#222;padding:15px}body{color:#222;text-align:unset;margin:7% auto 0;max-width:390px;min-height:180px;padding:30px 0 15px;}* > body{background:url(//www.google.com/images/errors/robot.png) 100% 5px no-repeat;padding-right:205px}p{margin:11px 0 22px;overflow:hidden}pre{white-space:pre-wrap;}ins{color:#777;text-decoration:none}a img{border:0}@media screen and (max-width:772px){body{background:none;margin-top:0;max-width:none;padding-right:0}}#logo{background:url(//www.google.com/images/branding/googlelogo/1x/googlelogo_color_150x54dp.png) no-repeat;margin-left:-5px}@media only screen and (min-resolution:192dpi){#logo{background:url(//www.google.com/images/branding/googlelogo/2x/googlelogo_color_150x54dp.pn
# ...

# %%
data = json.loads(response.text.split('\n')[1])

# %%
pd.DataFrame(data['default']['timelineData'])
# Out:
#           time formattedTime formattedAxisTime  value  hasData formattedValue
# 0   1634688000  Oct 20, 2021            Oct 20    [0]  [False]            [0]
# 1   1634774400  Oct 21, 2021            Oct 21    [0]  [False]            [0]
# 2   1634860800  Oct 22, 2021            Oct 22    [0]  [False]            [0]
# 3   1634947200  Oct 23, 2021            Oct 23    [0]  [False]            [0]
# 4   1635033600  Oct 24, 2021            Oct 24    [0]  [False]            [0]
# 5   1635120000  Oct 25, 2021            Oct 25    [0]  [False]            [0]
# 6   1635206400  Oct 26, 2021            Oct 26   [32]   [True]           [32]
# 7   1635292800  Oct 27, 2021            Oct 27   [32]   [True]           [32]
# 8   1635379200  Oct 28, 2021            Oct 28   [65]   [True]           [65]
# 9   1635465600  Oct 29, 2021            Oct 29    [0]  [False]            [0]
# 10  1635552000  Oct 30, 2021            Oct 30    [0]  [False]            [0]
# ...
